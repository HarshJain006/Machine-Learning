# %%
import pandas as pd
import numpy as np
import os
os.chdir(r"C:\Training\Academy\Statistics (Python)\Datasets")
import matplotlib.pyplot as plt

# %%
passengers = pd.read_csv("AirPassengers.csv", index_col=0)
passengers.plot()
plt.title("Monthly Passengers")
plt.show()

# %%
passengers.index = pd.DatetimeIndex( passengers.index ).to_period("M")
type(passengers.index)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
m_pass = passengers.resample('Q').sum()
m_pass.index.rename('Quarter', inplace=True)
m_pass.plot()
plt.title("Quarterly Passengers")
plt.show()
# Out:
# C:\Users\Sanjay Sane\AppData\Local\Temp\ipykernel_2552\1312434695.py:1: FutureWarning: Resampling with a PeriodIndex is deprecated. Cast index to DatetimeIndex before resampling instead.
#   m_pass = passengers.resample('Q').sum()

# %%
y_pass = passengers.resample('Y').sum()
y_pass.index.rename('Year', inplace=True)
y_pass.plot()
plt.title("Yearly Passengers")
plt.show()
# Out:
# C:\Users\Sanjay Sane\AppData\Local\Temp\ipykernel_2552\739211004.py:1: FutureWarning: Resampling with a PeriodIndex is deprecated. Cast index to DatetimeIndex before resampling instead.
#   y_pass = passengers.resample('Y').sum()

# %% [markdown]
# #### Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
passengers = pd.read_csv("AirPassengers.csv", index_col=0)
result = seasonal_decompose(passengers['Passengers'], model='additive',period=12)
result.plot()
# fig_size = plt.rcParams["figure.figsize"]
# fig_size[0] = 6
# fig_size[1] = 4.4
# plt.rcParams["figure.figsize"] = fig_size
# plt.title("Additive Decomposition")
plt.show()

# %%
result = seasonal_decompose(passengers['Passengers'], model='multiplicative',period=12)
result.plot()
plt.title("Multiplicative Decomposition")
plt.show()

# %% [markdown]
# #### Centered Moving Average (Rolling Centered Mean)

# %%
y = passengers['Passengers']

# %%
span=3
fcast = y.rolling(span,center=True).mean()
plt.plot(y, label='Data')
plt.plot(fcast, label='Centered Rolling Mean')
plt.legend(loc='best')
plt.show()

# %%
span=3
fcast = y.rolling(span,center=True).mean()
plt.plot(fcast, label='Centered Rolling Mean')
plt.legend(loc='best')
plt.show()

# %%
span=3
fcast = y.rolling(span,center=True).mean()
plt.plot(y, label='Data')
plt.legend(loc='best')
plt.show()
