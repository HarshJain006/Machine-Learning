# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
data = pd.read_csv('/content/spam.csv', encoding= 'latin-1')
data = data[['v1', 'v2']] #select only neccesary columns
data.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
data = pd.read_csv("spam.csv", encoding='latin-1')
data = data[['v1', 'v2']]
data.columns = ['label', 'message']
data['label'] = data['label'].map({'ham': 0, 'spam': 1})

X_train, X_test, y_test, y_train= train_test_split(data['message'],  data['label'], test_size=0.25, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# Feature extraction
vectorizer = CountVectorizer()
X_train_transformed = vectorizer.fit_transform(X_train)
X_test_transformed = vectorizer.transform(X_test)

# Model training
nb_classifier = MultinomialNB()
nb_classifier.fit(X_train_transformed, y_train)

# Predictions
y_pred = nb_classifier.predict(X_test_transformed)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))


# Test with custom messages
def predict_message(message):
    message_transformed = vectorizer.transform([message])
    prediction = nb_classifier.predict(message_transformed)
    return "Spam" if prediction[0] == 1 else "Not Spam"


print(predict_message("Congratulations! You've won a $1000 gift card!"))
print(predict_message("Are we still on for the meeting tomorrow?"))
# Out:
# (4179,) (1393,) (1393,) (4179,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-6401936e9209> in <cell line: 16>()
#      14 # Model training
#      15 nb_classifier = MultinomialNB()
# ---> 16 nb_classifier.fit(X_train_transformed, y_train)
#      17
#      18 # Predictions
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     730             Returns the instance itself.
#     731         """
# --> 732         X, y = self._check_X_y(X, y)
#     733         _, n_features = X.shape
#     734
#
# ...
