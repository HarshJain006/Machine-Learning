# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures

# %%
df=pd.read_csv("Boston.csv")
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
X=df[['lstat']] #here we make this as 2D array because .fit method does not accept 1D array for X
y=df['medv']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)

# %%
lr=LinearRegression()
lr.fit(X_train, y_train)

y_pred=lr.predict(X_test)

r2_score(y_test, y_pred)

#lr.fit(X_train.values.reshape(-1,1), y_train)
# Out:
# 0.5279301917445975

# %% [markdown]
# # **POLYNOMIAL FEATURES**

# %%
poly=PolynomialFeatures(degree=2,include_bias=False).set_output(transform='pandas')

X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test) #never apply fit transform here for X_test
lr.fit(X_train_poly, y_train)
# print(X_train_poly)

y_pred_poly=lr.predict(X_test_poly)

r2_score(y_test, y_pred_poly)
# Out:
# 0.6431149312301052

# %%
poly=PolynomialFeatures(degree=3,include_bias=False).set_output(transform='pandas')

X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test) #never apply fit transform here for X_test
lr.fit(X_train_poly, y_train)
# print(X_train_poly)

y_pred_poly=lr.predict(X_test_poly)

r2_score(y_test, y_pred_poly)
# Out:
# 0.6464637609380741

# %%
poly=PolynomialFeatures(degree=4,include_bias=False).set_output(transform='pandas')

X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test) #never apply fit transform here for X_test
lr.fit(X_train_poly, y_train)
# print(X_train_poly)

y_pred_poly=lr.predict(X_test_poly)

r2_score(y_test, y_pred_poly)
# Out:
# 0.6397924587030076

# %% [markdown]
# # Taking 2 variables 'rad' and 'lstat'

# %%
X=df[['lstat', 'rad']]
y=df['medv']

# %%
X=df.drop('medv',axis=1)
y=df['medv']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)

# %%
lr=LinearRegression()
lr.fit(X_train, y_train)

y_pred=lr.predict(X_test)

r2_score(y_test, y_pred)
# Out:
# 0.5260520682885452

# %%
poly=PolynomialFeatures(degree=2,include_bias=False).set_output(transform='pandas')

X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test) #never apply fit transform here for X_test
lr.fit(X_train_poly, y_train)
# print(X_train_poly)

y_pred_poly=lr.predict(X_test_poly)

r2_score(y_test, y_pred_poly)
# Out:
# 0.6950286613601392

# %%
X_train_poly.columns # here we have columns x1, x2, x1*x2=interaction column, x1**2, x2**2
# Out:
# Index(['medv', 'medv^2'], dtype='object')

# %%
poly=PolynomialFeatures(degree=3,include_bias=False).set_output(transform='pandas')

X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test) #never apply fit transform here for X_test
lr.fit(X_train_poly, y_train)
# print(X_train_poly)

y_pred_poly=lr.predict(X_test_poly)

r2_score(y_test, y_pred_poly)
# Out:
# -8442.445263155329

# %%
X_train_poly.columns # here we have columns x1, x2, x1*x2=interaction column, x1**2, x2**2,x1**3, ,x1**2*x2,x2**3
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        ...
#        'ptratio^2 lstat^2', 'ptratio black^3', 'ptratio black^2 lstat',
#        'ptratio black lstat^2', 'ptratio lstat^3', 'black^4', 'black^3 lstat',
#        'black^2 lstat^2', 'black lstat^3', 'lstat^4'],
#       dtype='object', length=2379)

# %%
poly=PolynomialFeatures(degree=4,include_bias=False).set_output(transform='pandas')

X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test) #never apply fit transform here for X_test
lr.fit(X_train_poly, y_train)
# print(X_train_poly)

y_pred_poly=lr.predict(X_test_poly)

r2_score(y_test, y_pred_poly)
# Out:
# -1370.9553198662918

# %% [markdown]
# Using Pipelines

# %%
from sklearn.pipeline import  Pipeline
poly = PolynomialFeatures(degree=2, include_bias= False).set_output(transform= 'pipeline ')
lr=LinearRegression
pipe= pipeline(['POLY',poly),(,

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression

ohe = OneHotEncoder(sparse_output=False, drop='first',).set_output(transform='pandas')
X_encoded = ohe.fit_transform(X)  # Store the transformed data

lr_LinearRegression = LinearRegression()
lr_LinearRegression.fit(X_encoded, y)  # Fit the model to the encoded data and target variable 'y'

# Now you can access the intercept and coefficients
lr_LinearRegression.intercept_, lr_LinearRegression.coef_
# Out:
# (25.009331897287733,
#  array([ 1.04838583,  1.0522189 ,  0.70971576, ..., -1.27051666,
#         -0.75378962, -1.03663479]))

# %%
import statsmodels.api as sm
import numpy as np

# Sample data
X = np.array([1, 2, 3, 4, 5])

# Add constant
X = sm.add_constant(X)
print(X)
# Out:
# [[1. 1.]
#  [1. 2.]
#  [1. 3.]
#  [1. 4.]
#  [1. 5.]]
