# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, log_loss
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer 
from sklearn.compose import make_column_selector
import warnings
from sklearn.ensemble import StackingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
cancer = pd.read_csv(r"C:\Training\Academy\Statistics (Python)\Cases\Wisconsin\BreastCancer.csv",index_col=0)
X = cancer.drop('Class', axis=1)
y = cancer['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=24, test_size=0.3, stratify=y)

# %%
knn = KNeighborsClassifier()
nb = GaussianNB()
dtc = DecisionTreeClassifier(random_state=24)
svm = SVC(probability=True, random_state=24)
lr = LogisticRegression(random_state=24)
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],
                           final_estimator=lr)

# %%
stack.fit(X_train, y_train)
y_pred = stack.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9714285714285714

# %%
y_pred_prob = stack.predict_proba(X_test)[:,1]
print(roc_auc_score(y_test, y_pred_prob))
# Out:
# 0.990841384863124

# %% [markdown]
# Using `passthrough=True` option

# %%
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],
                           final_estimator=lr, passthrough=True)
stack.fit(X_train, y_train)
y_pred = stack.predict(X_test)
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9714285714285714

# %%
y_pred_prob = stack.predict_proba(X_test)[:,1]
print(roc_auc_score(y_test, y_pred_prob))
# Out:
# 0.9959742351046699

# %% [markdown]
# ## Glass Identification

# %%
glass = pd.read_csv(r"C:\Training\Academy\Statistics (Python)\Cases\Glass Identification\Glass.csv")
X = glass.drop('Type', axis=1)
y = glass['Type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=24, test_size=0.3, stratify=y)
knn = KNeighborsClassifier()
nb = GaussianNB()
dtc = DecisionTreeClassifier(random_state=24)
svm = SVC(probability=True, random_state=24)
lr = LogisticRegression(random_state=24)

# %% [markdown]
# w/o `passthrough`

# %%
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],
                           final_estimator=lr)
stack.fit(X_train, y_train)
y_pred = stack.predict(X_test)
print(accuracy_score(y_test, y_pred))
y_pred_prob = stack.predict_proba(X_test)
print(log_loss(y_test, y_pred_prob))
# Out:
# 0.7230769230769231
# 0.7261085625838982

# %% [markdown]
# with `passthrough`

# %%
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],
                           final_estimator=lr, passthrough=True)
stack.fit(X_train, y_train)
y_pred = stack.predict(X_test)
print(accuracy_score(y_test, y_pred))
y_pred_prob = stack.predict_proba(X_test)
print(log_loss(y_test, y_pred_prob))
# Out:
# 0.7076923076923077
# 0.7747824074555355
# C:\Python\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Grid Search

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
rf = RandomForestClassifier(random_state=24)
stack = StackingClassifier(estimators=[('KNN',knn),('NB',nb),('TREE',dtc),('SVM',svm)],
                           final_estimator=rf)
stack.get_params()
# Out:
# {'cv': None,
#  'estimators': [('KNN', KNeighborsClassifier()),
#   ('NB', GaussianNB()),
#   ('TREE', DecisionTreeClassifier(random_state=24)),
#   ('SVM', SVC(probability=True, random_state=24))],
#  'final_estimator__bootstrap': True,
#  'final_estimator__ccp_alpha': 0.0,
#  'final_estimator__class_weight': None,
#  'final_estimator__criterion': 'gini',
#  'final_estimator__max_depth': None,
#  'final_estimator__max_features': 'sqrt',
#  'final_estimator__max_leaf_nodes': None,
#  'final_estimator__max_samples': None,
#  'final_estimator__min_impurity_decrease': 0.0,
#  'final_estimator__min_samples_leaf': 1,
#  'final_estimator__min_samples_split': 2,
#  'final_estimator__min_weight_fraction_leaf': 0.0,
#  'final_estimator__monotonic_cst': None,
#  'final_estimator__n_estimators': 10,
#  'final_estimator__n_jobs': None,
#  'final_estimator__oob_score': True,
#  'final_estimator__random_state': 24,
#  'final_estimator__verbose': 0,
#  'final_estimator__warm_start': False,
#  'final_estimator': RandomForestClassifier(n_estimators=10, oob_score=True, random_state=24),
#  'n_jobs': None,
#  'passthrough': False,
#  'stack_method': 'auto',
#  'verbose': 0,
#  'KNN': KNeighborsClassifier(),
#  'NB': GaussianNB(),
#  'TREE': DecisionTreeClassifier(random_state=24),
#  'SVM': SVC(probability=True, random_state=24),
#  'KNN__algorithm': 'auto',
#  'KNN__leaf_size': 30,
#  'KNN__metric': 'minkowski',
#  'KNN__metric_params': None,
#  'KNN__n_jobs': None,
#  'KNN__n_neighbors': 5,
#  'KNN__p': 2,
#  'KNN__weights': 'uniform',
#  'NB__priors': None,
#  'NB__var_smoothing': 1e-09,
#  'TREE__ccp_alpha': 0.0,
#  'TREE__class_weight': None,
#  'TREE__criterion': 'gini',
#  'TREE__max_depth': None,
#  'TREE__max_features': None,
#  'TREE__max_leaf_nodes': None,
#  'TREE__min_impurity_decrease': 0.0,
#  'TREE__min_samples_leaf': 1,
#  'TREE__min_samples_split': 2,
#  'TREE__min_weight_fraction_leaf': 0.0,
#  'TREE__monotonic_cst': None,
#  'TREE__random_state': 24,
#  'TREE__splitter': 'best',
#  'SVM__C': 1.0,
#  'SVM__break_ties': False,
#  'SVM__cache_size': 200,
#  'SVM__class_weight': None,
#  'SVM__coef0': 0.0,
#  'SVM__decision_function_shape': 'ovr',
#  'SVM__degree': 3,
#  'SVM__gamma': 'scale',
#  'SVM__kernel': 'rbf',
#  'SVM__max_iter': -1,
#  'SVM__probability': True,
#  'SVM__random_state': 24,
#  'SVM__shrinking': True,
#  'SVM__tol': 0.001,
#  'SVM__verbose': False}

# %%
params = {'final_estimator__max_depth':[3,4,5] , 'SVM__C':np.linspace(0.001, 3, 5),
          'TREE__max_depth':[None, 2, 4], 'final_estimator__n_estimators':[10, 50],
          'passthrough':[True, False]}
gcv = GridSearchCV(stack, param_grid=params, cv=kfold, scoring='neg_log_loss',verbose=3)
gcv.fit(X, y)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.696 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.924 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.974 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.867 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.919 total time=   0.0s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.758 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.914 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.929 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.868 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.071 total time=   0.0s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.748 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.881 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.893 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.857 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.945 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.821 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.890 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.933 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.830 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.027 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.691 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.889 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.607 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.759 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.848 total time=   0.0s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.810 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.884 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.557 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.906 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.820 total time=   0.0s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.702 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.823 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.831 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.789 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.889 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.769 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.847 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.877 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.801 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-1.007 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.723 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.820 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.597 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.468 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.929 total time=   0.0s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.713 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.697 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.860 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.831 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.806 total time=   0.0s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.687 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.794 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.864 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.761 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.882 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.757 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.834 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.858 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.787 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=None, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-1.032 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.809 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.910 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.953 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.866 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=True;, score=-0.918 total time=   0.0s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.830 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.956 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.897 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.851 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.028 total time=   0.0s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.769 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.894 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.902 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.855 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.919 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.812 total time=   0.1s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.906 total time=   0.1s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.922 total time=   0.1s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.864 total time=   0.1s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.021 total time=   0.1s
# [CV 1/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.469 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.913 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.843 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.755 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, TREE__max_depth=2, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0

# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-0.811 total time=   0.0s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=10, passthrough=False;, score=-1.046 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.745 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.883 total time=   0.2s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.857 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.858 total time=   0.2s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=True;, score=-0.919 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.787 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.884 total time=   0.2s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.921 total time=   0.2s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-0.838 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=3, final_estimator__n_estimators=50, passthrough=False;, score=-1.017 total time=   0.3s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.742 total time=   0.2s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.942 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.824 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-1.497 total time=   0.2s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=True;, score=-0.961 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.737 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.933 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.757 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-0.781 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=10, passthrough=False;, score=-1.708 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.697 total time=   0.3s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.850 total time=   0.2s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.785 total time=   0.2s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.769 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=True;, score=-0.859 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.718 total time=   0.2s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.892 total time=   0.2s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.805 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.781 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=4, final_estimator__n_estimators=50, passthrough=False;, score=-0.961 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.809 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.878 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.823 total time=   0.0s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-1.597 total time=   0.0s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=True;, score=-0.989 total time=   0.0s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.779 total time=   0.0s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.867 total time=   0.0s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.803 total time=   0.0s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-0.709 total time=   0.0s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=10, passthrough=False;, score=-1.737 total time=   0.0s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.609 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.793 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.767 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.757 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=True;, score=-0.831 total time=   0.1s
# [CV 1/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.710 total time=   0.1s
# [CV 2/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.788 total time=   0.1s
# [CV 3/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.779 total time=   0.1s
# [CV 4/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.772 total time=   0.1s
# [CV 5/5] END SVM__C=3.0, TREE__max_depth=4, final_estimator__max_depth=5, final_estimator__n_estimators=50, passthrough=False;, score=-0.989 total time=   0.1s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=24, shuffle=True),
#              estimator=StackingClassifier(estimators=[('KNN',
#                                                        KNeighborsClassifier()),
#                                                       ('NB', GaussianNB()),
#                                                       ('TREE',
#                                                        DecisionTreeClassifier(random_state=24)),
#                                                       ('SVM',
#                                                        SVC(probability=True,
#                                                            random_state=24))],
#                                           final_estimator=RandomForestClassifier(n_estimators=10,
#                                                                                  oob_score=True,
#                                                                                  random_state=24)),
#              param_grid={'SVM__C': array([1.00000e-03, 7.50750e-01, 1.50050e+00, 2.25025e+00, 3.00000e+00]),
#                          'TREE__max_depth': [None, 2, 4],
#                          'final_estimator__max_depth': [3, 4, 5],
#                          'final_estimator__n_estimators': [10, 50],
#                          'passthrough': [True, False]},
#              scoring='neg_log_loss', verbose=3)

# %%
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'SVM__C': 3.0, 'TREE__max_depth': 2, 'final_estimator__max_depth': 5, 'final_estimator__n_estimators': 50, 'passthrough': True}
# -0.7486144895037242

# %% [markdown]
# ## Serializing the fitted object

# %%
best_stack = gcv.best_estimator_

# %%
import pickle 
pkfile = open("C:/Training/Academy/Statistics (Python)/Cases/Glass Identification/stack_gls.pkl", 'wb') 
pickle.dump(best_stack, pkfile)

# %%
best_stack
# Out:
# StackingClassifier(estimators=[('KNN', KNeighborsClassifier()),
#                                ('NB', GaussianNB()),
#                                ('TREE',
#                                 DecisionTreeClassifier(max_depth=2,
#                                                        random_state=24)),
#                                ('SVM',
#                                 SVC(C=3.0, probability=True, random_state=24))],
#                    final_estimator=RandomForestClassifier(max_depth=5,
#                                                           n_estimators=50,
#                                                           oob_score=True,
#                                                           random_state=24),
#                    passthrough=True)
