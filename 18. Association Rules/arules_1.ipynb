# %%
import mlxtend
mlxtend.__version__
# Out:
# '0.23.3'

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import os
os.chdir(r'C:\Training\Academy\Statistics (Python)\Datasets')

# %%
fp_df = pd.read_csv('Faceplate.csv',index_col=0)
fp_df = fp_df.astype(bool)

# %%
itemsets = apriori(fp_df, min_support=0.2, use_colnames=True)
rules = association_rules(itemsets, metric='lift', min_threshold=1,
                          num_itemsets=len(fp_df),
                          return_metrics=[ 'support', 'confidence', 'lift'])
rules.sort_values('confidence', ascending=False)
# Out:
#        antecedents     consequents  support  confidence      lift
# 3          (Green)           (Red)      0.2    1.000000  1.666667
# 5         (Orange)         (White)      0.2    1.000000  1.428571
# 7          (Green)         (White)      0.2    1.000000  1.428571
# 9   (White, Green)           (Red)      0.2    1.000000  1.666667
# 10    (Red, Green)         (White)      0.2    1.000000  1.428571
# 13         (Green)    (White, Red)      0.2    1.000000  2.500000
# 0            (Red)          (Blue)      0.4    0.666667  1.111111
# 1           (Blue)           (Red)      0.4    0.666667  1.111111
# 8     (White, Red)         (Green)      0.2    0.500000  2.500000
# 2            (Red)         (Green)      0.2    0.333333  1.666667
# 12           (Red)  (White, Green)      0.2    0.333333  1.666667
# 4          (White)        (Orange)      0.2    0.285714  1.428571
# 6          (White)         (Green)      0.2    0.285714  1.428571
# 11         (White)    (Red, Green)      0.2    0.285714  1.428571

# %% [markdown]
# ### Cosmetics

# %%
cosmetics = pd.read_csv("Cosmetics.csv", index_col=0)
cosmetics.head(2)
# Out:
#          Bag  Blush  Nail Polish  Brushes  Concealer  Eyebrow Pencils  \
# Trans.
# 1          0      1            1        1          1                0
# 2          0      0            1        0          1                0
#
#          Bronzer  Lip liner  Mascara  Eye shadow  Foundation  Lip Gloss  \
# Trans.
# 1              1          1        1           0           0          0
# 2              1          1        0           0           1          1
#
#          Lipstick  Eyeliner
# Trans.
# 1               0         1
# 2               0         0

# %%
itemsets = apriori(cosmetics, min_support=0.2, use_colnames=True)
rules = association_rules(itemsets, metric='lift', min_threshold=1,
                          num_itemsets=len(cosmetics),
                          return_metrics=[ 'support', 'confidence', 'lift'])
rules.sort_values('confidence', ascending=False)
# Out:
# C:\Python\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#      antecedents   consequents  support  confidence      lift
# 10     (Mascara)  (Eye shadow)    0.321    0.899160  2.359999
# 11  (Eye shadow)     (Mascara)    0.321    0.842520  2.359999
# 16   (Lip Gloss)  (Foundation)    0.356    0.726531  1.355468
# 9    (Concealer)    (Eyeliner)    0.297    0.671946  1.470341
# 17  (Foundation)   (Lip Gloss)    0.356    0.664179  1.355468
# 8     (Eyeliner)   (Concealer)    0.297    0.649891  1.470341
# 1        (Blush)   (Concealer)    0.220    0.606061  1.371178
# 2      (Mascara)   (Concealer)    0.204    0.571429  1.292825
# 13  (Eye shadow)  (Foundation)    0.211    0.553806  1.033220
# 5   (Eye shadow)   (Concealer)    0.201    0.527559  1.193573
# 15  (Eye shadow)   (Lip Gloss)    0.201    0.527559  1.076651
# 0    (Concealer)       (Blush)    0.220    0.497738  1.371178
# 18    (Eyeliner)   (Lip Gloss)    0.227    0.496718  1.013710
# 6    (Concealer)   (Lip Gloss)    0.218    0.493213  1.006556
# 19   (Lip Gloss)    (Eyeliner)    0.227    0.463265  1.013710
# 3    (Concealer)     (Mascara)    0.204    0.461538  1.292825
# 4    (Concealer)  (Eye shadow)    0.201    0.454751  1.193573
# 7    (Lip Gloss)   (Concealer)    0.218    0.444898  1.006556
# 14   (Lip Gloss)  (Eye shadow)    0.201    0.410204  1.076651
# 12  (Foundation)  (Eye shadow)    0.211    0.393657  1.033220
