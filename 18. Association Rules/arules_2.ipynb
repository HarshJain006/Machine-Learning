# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder
import os
os.chdir(r'C:\Training\Academy\Statistics (Python)\Datasets')

# %%
groceries = []
with open("groceries.csv","r") as f:groceries = f.read()
groceries = groceries.split("\n")

groceries_list = []
for i in groceries:
    groceries_list.append(i.split(","))
groceries_list[:3]
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk']]

# %%
te = TransactionEncoder().set_output(transform='pandas')
te_ary = te.fit_transform(groceries_list)
itemsets = apriori(te_ary, min_support=0.01, use_colnames=True)
rules = association_rules(itemsets, metric='lift', min_threshold=1,
                          num_itemsets=len(te_ary),
                          return_metrics=[ 'support', 'confidence', 'lift'])
rules.sort_values('confidence', ascending=False)
# Out:
#                            antecedents                  consequents   support  \
# 418    (citrus fruit, root vegetables)           (other vegetables)  0.010371
# 491  (root vegetables, tropical fruit)           (other vegetables)  0.012303
# 438                     (yogurt, curd)                 (whole milk)  0.010066
# 413         (butter, other vegetables)                 (whole milk)  0.011490
# 570  (root vegetables, tropical fruit)                 (whole milk)  0.011998
# ..                                 ...                          ...       ...
# 434                       (whole milk)       (citrus fruit, yogurt)  0.010269
# 470                       (whole milk)     (pork, other vegetables)  0.010168
# 512                       (whole milk)  (sausage, other vegetables)  0.010168
# 439                       (whole milk)               (yogurt, curd)  0.010066
# 215                       (whole milk)                (hard cheese)  0.010066
#
#      confidence      lift
# ...
